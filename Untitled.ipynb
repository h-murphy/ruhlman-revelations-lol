# %%
import json

with open('hist.json', 'r') as fp:
    histdict = json.load(fp)

with open('mus.json', 'r') as fp:
    musdict = json.load(fp)
    
with open('wom.json', 'r') as fp:
    womdict = json.load(fp)

with open('wom.json', 'r') as fp:
    womdict = json.load(fp)

with open('pol.json', 'r') as fp:
    poldict = json.load(fp)
    
with open('soc.json', 'r') as fp:
    socdict = json.load(fp)
    
with open('cs.json', 'r') as fp:
    csdict = json.load(fp)
    
with open('psych.json', 'r') as fp:
    psychdict = json.load(fp)
    
with open('econ.json', 'r') as fp:
    econdict = json.load(fp)
    
with open('art.json', 'r') as fp:
    artdict = json.load(fp)
    
with open('eng.json', 'r') as fp:
    engdict = json.load(fp)
    
with open('bio.json', 'r') as fp:
    biodict = json.load(fp)

with open('ruhlbio.json', 'r') as fp:
    biodictruhl = json.load(fp)
    
with open('ruhlhist.json', 'r') as fp:
    histdictruhl = json.load(fp)

with open('ruhlmus.json', 'r') as fp:
    musdictruhl = json.load(fp)
    
with open('ruhlwom.json', 'r') as fp:
    womdictruhl = json.load(fp)

with open('ruhlpol.json', 'r') as fp:
    poldictruhl = json.load(fp)
    
with open('ruhlsoc.json', 'r') as fp:
    socdictruhl = json.load(fp)
    
with open('ruhlcs.json', 'r') as fp:
    csdictruhl = json.load(fp)
    
with open('ruhlpsych.json', 'r') as fp:
    psychdictruhl = json.load(fp)
    
with open('ruhlecon.json', 'r') as fp:
    econdictruhl = json.load(fp)
    
with open('ruhlart.json', 'r') as fp:
    artdictruhl = json.load(fp)
    
with open('ruhleng.json', 'r') as fp:
    engdictruhl = json.load(fp)
    
with open('ruhlbio.json', 'r') as fp:
    biodictruhl = json.load(fp)

# %%
def normalize(data):
      return {k: v / data['total_words'] for k, v in data.items()}

# %%
d2 = {}
for k, v in biodict.items():
    print('k ', k)
    print('v ', v)
# Out:
# k  human
# v  1
# k  take
# v  5
# k  perform
# v  1
# k  lab
# v  21
# k  get
# v  2
# k  coloni
# v  1
# k  where
# v  1
# k  and
# v  27
# k  ever
# v  1
# k  so
# v  3
# k  signific
# v  1
# k  who
# v  1
# k  actual
# v  1
# k  that
# v  8
# k  neurosci
# v  1
# k  bio
# v  4
# k  plenti
# v  1
# k  system
# v  1
# k  paper
# v  3
# k  pre-m
# v  1
# k  addit
# v  1
# k  alot
# v  1
# k  read
# v  4
# k  want
# v  1
# k  is
# v  3
# k  resul
# v  1
# k  cool
# v  1
# k  certain
# v  1
# k  some
# v  3
# k  was
# v  1
# k  this
# v  6
# k  seem
# v  1
# k  dinner
# v  1
# k  form
# v  1
# k  exist
# v  1
# k  major
# v  5
# k  most
# v  3
# k  classism
# v  1
# k  test
# v  2
# k  higher
# v  1
# k  energi
# v  1
# k  in
# v  18
# k  eg
# v  2
# k  prospect
# v  1
# k  like
# v  2
# k  make
# v  1
# k  varieti
# v  1
# k  academia
# v  1
# k  as
# v  6
# k  critic
# v  1
# k  type
# v  1
# k  book
# v  1
# k  figur
# v  1
# k  them
# v  4
# k  200-level
# v  1
# k  but
# v  2
# k  teach
# v  1
# k  about
# v  8
# k  imagin
# v  1
# k  i'm
# v  1
# k  often
# v  1
# k  data
# v  1
# k  connect
# v  2
# k  udi
# v  1
# k  bate
# v  1
# k  spend
# v  4
# k  doe
# v  1
# k  around
# v  1
# k  thousand
# v  1
# k  eat
# v  1
# k  i
# v  12
# k  how
# v  4
# k  of
# v  32
# k  inform
# v  2
# k  such
# v  1
# k  respiratori
# v  1
# k  might
# v  1
# k  lectur
# v  4
# k  etc
# v  1
# k  textbook
# v  1
# k  the
# v  19
# k  know
# v  2
# k  do
# v  6
# k  dept
# v  1
# k  session
# v  1
# k  neuro
# v  1
# k  they
# v  12
# k  less
# v  1
# k  macro
# v  1
# k  sexism
# v  1
# k  nighter
# v  1
# k  thing
# v  1
# k  coupl
# v  1
# k  on
# v  3
# k  i'v
# v  1
# k  easier
# v  1
# k  all
# v  3
# k  out
# v  1
# k  upper
# v  1
# k  my
# v  1
# k  sort
# v  1
# k  work
# v  6
# k  coursework
# v  1
# k  plant
# v  2
# k  lot
# v  15
# k  talk
# v  2
# k  interpret
# v  1
# k  level
# v  2
# k  experi
# v  4
# k  differ
# v  1
# k  probabl
# v  3
# k  sampl
# v  1
# k  into
# v  1
# k  memor
# v  7
# k  look
# v  2
# k  wellesley
# v  1
# k  be
# v  1
# k  with
# v  2
# k  depart
# v  2
# k  way
# v  1
# k  amount
# v  1
# k  pset
# v  2
# k  bacteria
# v  1
# k  particular
# v  1
# k  not
# v  3
# k  --
# v  1
# k  one
# v  1
# k  scientif
# v  1
# k  health
# v  1
# k  organ
# v  2
# k  set
# v  2
# k  also
# v  6
# k  fact
# v  1
# k  class
# v  4
# k  tri
# v  3
# k  well
# v  2
# k  exampl
# v  1
# k  studi
# v  1
# k  outsid
# v  1
# k  too
# v  2
# k  involv
# v  2
# k  are
# v  4
# k  ecosystem
# v  1
# k  center
# v  2
# k  els
# v  1
# k  cell
# v  7
# k  report
# v  4
# k  chem
# v  1
# k  took
# v  1
# k  educ
# v  1
# k  it
# v  2
# k  write
# v  3
# k  cover
# v  1
# k  live
# v  1
# k  success
# v  1
# k  pipett
# v  1
# k  more
# v  2
# k  cours
# v  2
# k  mayb
# v  2
# k  experiment
# v  1
# k  analyz
# v  1
# k  topic
# v  3
# k  solv
# v  1
# k  cissex
# v  1
# k  anim
# v  3
# k  pull
# v  1
# k  sciences;
# v  1
# k  mechan
# v  1
# k  suffer
# v  1
# k  scienc
# v  7
# k  their
# v  4
# k  necessarili
# v  1
# k  for
# v  1
# k  -
# v  1
# k  seminar
# v  1
# k  piec
# v  1
# k  biolog
# v  7
# k  subject
# v  1
# k  endless
# v  1
# k  cellular
# v  1
# k  other
# v  2
# k  although
# v  1
# k  student
# v  5
# k  larg
# v  1
# k  would
# v  1
# k  research
# v  3
# k  campus
# v  1
# k  world
# v  1
# k  bio-chem
# v  1
# k  peopl
# v  1
# k  math
# v  1
# k  singl
# v  1
# k  see
# v  1
# k  focus
# v  2
# k  matter
# v  1
# k  learn
# v  6
# k  week
# v  1
# k  pictur
# v  2
# k  pre-med/publ
# v  1
# k  have
# v  4
# k  think
# v  8
# k  anatomi
# v  1
# k  real
# v  1
# k  translat
# v  1
# k  racism
# v  1
# k  these
# v  1
# k  field
# v  1
# k  rote
# v  2
# k  time
# v  5
# k  from
# v  1
# k  hands-on
# v  1
# k  dissect
# v  1
# k  meant
# v  1
# k  a
# v  19
# k  to
# v  10
# k  interest
# v  1
# k  then
# v  1
# k  go
# v  1
# k  term
# v  1
# k  chemistri
# v  3
# k  enough
# v  1
# k  inher
# v  1
# k  structur
# v  1
# k  everi
# v  1
# k  microscop
# v  1
# k  than
# v  1
# k  togeth
# v  1
# k  what
# v  3
# k  total_words
# v  616
# k  stuff
# v  1
# k  design
# v  1
# k  problem
# v  3
# k  sure
# v  1
# k  function
# v  1
# k  fun
# v  1
# k  aren't
# v  1
# k  there
# v  3
# k  micro
# v  2
# k  explor
# v  1
# k  attend
# v  1
# k  basic
# v  1
# k  becaus
# v  2
# k  blood
# v  1
# k  heard
# v  1
# k  at
# v  3
# k  physic
# v  1

# %%
normalize(biodict)
# Out:
# {'-': 0.0016233766233766235,
#  '--': 0.0016233766233766235,
#  '200-level': 0.0016233766233766235,
#  'a': 0.030844155844155844,
#  'about': 0.012987012987012988,
#  'academia': 0.0016233766233766235,
#  'actual': 0.0016233766233766235,
#  'addit': 0.0016233766233766235,
#  'all': 0.00487012987012987,
#  'alot': 0.0016233766233766235,
#  'also': 0.00974025974025974,
#  'although': 0.0016233766233766235,
#  'amount': 0.0016233766233766235,
#  'analyz': 0.0016233766233766235,
#  'anatomi': 0.0016233766233766235,
#  'and': 0.04383116883116883,
#  'anim': 0.00487012987012987,
#  'are': 0.006493506493506494,
#  "aren't": 0.0016233766233766235,
#  'around': 0.0016233766233766235,
#  'as': 0.00974025974025974,
#  'at': 0.00487012987012987,
#  'attend': 0.0016233766233766235,
#  'bacteria': 0.0016233766233766235,
#  'basic': 0.0016233766233766235,
#  'bate': 0.0016233766233766235,
#  'be': 0.0016233766233766235,
#  'becaus': 0.003246753246753247,
#  'bio': 0.006493506493506494,
#  'bio-chem': 0.0016233766233766235,
#  'biolog': 0.011363636363636364,
#  'blood': 0.0016233766233766235,
#  'book': 0.0016233766233766235,
#  'but': 0.003246753246753247,
#  'campus': 0.0016233766233766235,
#  'cell': 0.011363636363636364,
#  'cellular': 0.0016233766233766235,
#  'center': 0.003246753246753247,
#  'certain': 0.0016233766233766235,
#  'chem': 0.0016233766233766235,
#  'chemistri': 0.00487012987012987,
#  'cissex': 0.0016233766233766235,
#  'class': 0.006493506493506494,
#  'classism': 0.0016233766233766235,
#  'coloni': 0.0016233766233766235,
#  'connect': 0.003246753246753247,
#  'cool': 0.0016233766233766235,
#  'coupl': 0.0016233766233766235,
#  'cours': 0.003246753246753247,
#  'coursework': 0.0016233766233766235,
#  'cover': 0.0016233766233766235,
#  'critic': 0.0016233766233766235,
#  'data': 0.0016233766233766235,
#  'depart': 0.003246753246753247,
#  'dept': 0.0016233766233766235,
#  'design': 0.0016233766233766235,
#  'differ': 0.0016233766233766235,
#  'dinner': 0.0016233766233766235,
#  'dissect': 0.0016233766233766235,
#  'do': 0.00974025974025974,
#  'doe': 0.0016233766233766235,
#  'easier': 0.0016233766233766235,
#  'eat': 0.0016233766233766235,
#  'ecosystem': 0.0016233766233766235,
#  'educ': 0.0016233766233766235,
#  'eg': 0.003246753246753247,
#  'els': 0.0016233766233766235,
#  'endless': 0.0016233766233766235,
#  'energi': 0.0016233766233766235,
#  'enough': 0.0016233766233766235,
#  'etc': 0.0016233766233766235,
#  'ever': 0.0016233766233766235,
#  'everi': 0.0016233766233766235,
#  'exampl': 0.0016233766233766235,
#  'exist': 0.0016233766233766235,
#  'experi': 0.006493506493506494,
#  'experiment': 0.0016233766233766235,
#  'explor': 0.0016233766233766235,
#  'fact': 0.0016233766233766235,
#  'field': 0.0016233766233766235,
#  'figur': 0.0016233766233766235,
#  'focus': 0.003246753246753247,
#  'for': 0.0016233766233766235,
#  'form': 0.0016233766233766235,
#  'from': 0.0016233766233766235,
#  'fun': 0.0016233766233766235,
#  'function': 0.0016233766233766235,
#  'get': 0.003246753246753247,
#  'go': 0.0016233766233766235,
#  'hands-on': 0.0016233766233766235,
#  'have': 0.006493506493506494,
#  'health': 0.0016233766233766235,
#  'heard': 0.0016233766233766235,
#  'higher': 0.0016233766233766235,
#  'how': 0.006493506493506494,
#  'human': 0.0016233766233766235,
#  'i': 0.01948051948051948,
#  "i'm": 0.0016233766233766235,
#  "i'v": 0.0016233766233766235,
#  'imagin': 0.0016233766233766235,
#  'in': 0.02922077922077922,
#  'inform': 0.003246753246753247,
#  'inher': 0.0016233766233766235,
#  'interest': 0.0016233766233766235,
#  'interpret': 0.0016233766233766235,
#  'into': 0.0016233766233766235,
#  'involv': 0.003246753246753247,
#  'is': 0.00487012987012987,
#  'it': 0.003246753246753247,
#  'know': 0.003246753246753247,
#  'lab': 0.03409090909090909,
#  'larg': 0.0016233766233766235,
#  'learn': 0.00974025974025974,
#  'lectur': 0.006493506493506494,
#  'less': 0.0016233766233766235,
#  'level': 0.003246753246753247,
#  'like': 0.003246753246753247,
#  'live': 0.0016233766233766235,
#  'look': 0.003246753246753247,
#  'lot': 0.024350649350649352,
#  'macro': 0.0016233766233766235,
#  'major': 0.008116883116883116,
#  'make': 0.0016233766233766235,
#  'math': 0.0016233766233766235,
#  'matter': 0.0016233766233766235,
#  'mayb': 0.003246753246753247,
#  'meant': 0.0016233766233766235,
#  'mechan': 0.0016233766233766235,
#  'memor': 0.011363636363636364,
#  'micro': 0.003246753246753247,
#  'microscop': 0.0016233766233766235,
#  'might': 0.0016233766233766235,
#  'more': 0.003246753246753247,
#  'most': 0.00487012987012987,
#  'my': 0.0016233766233766235,
#  'necessarili': 0.0016233766233766235,
#  'neuro': 0.0016233766233766235,
#  'neurosci': 0.0016233766233766235,
#  'nighter': 0.0016233766233766235,
#  'not': 0.00487012987012987,
#  'of': 0.05194805194805195,
#  'often': 0.0016233766233766235,
#  'on': 0.00487012987012987,
#  'one': 0.0016233766233766235,
#  'organ': 0.003246753246753247,
#  'other': 0.003246753246753247,
#  'out': 0.0016233766233766235,
#  'outsid': 0.0016233766233766235,
#  'paper': 0.00487012987012987,
#  'particular': 0.0016233766233766235,
#  'peopl': 0.0016233766233766235,
#  'perform': 0.0016233766233766235,
#  'physic': 0.0016233766233766235,
#  'pictur': 0.003246753246753247,
#  'piec': 0.0016233766233766235,
#  'pipett': 0.0016233766233766235,
#  'plant': 0.003246753246753247,
#  'plenti': 0.0016233766233766235,
#  'pre-m': 0.0016233766233766235,
#  'pre-med/publ': 0.0016233766233766235,
#  'probabl': 0.00487012987012987,
#  'problem': 0.00487012987012987,
#  'prospect': 0.0016233766233766235,
#  'pset': 0.003246753246753247,
#  'pull': 0.0016233766233766235,
#  'racism': 0.0016233766233766235,
#  'read': 0.006493506493506494,
#  'real': 0.0016233766233766235,
#  'report': 0.006493506493506494,
#  'research': 0.00487012987012987,
#  'respiratori': 0.0016233766233766235,
#  'resul': 0.0016233766233766235,
#  'rote': 0.003246753246753247,
#  'sampl': 0.0016233766233766235,
#  'scienc': 0.011363636363636364,
#  'sciences;': 0.0016233766233766235,
#  'scientif': 0.0016233766233766235,
#  'see': 0.0016233766233766235,
#  'seem': 0.0016233766233766235,
#  'seminar': 0.0016233766233766235,
#  'session': 0.0016233766233766235,
#  'set': 0.003246753246753247,
#  'sexism': 0.0016233766233766235,
#  'signific': 0.0016233766233766235,
#  'singl': 0.0016233766233766235,
#  'so': 0.00487012987012987,
#  'solv': 0.0016233766233766235,
#  'some': 0.00487012987012987,
#  'sort': 0.0016233766233766235,
#  'spend': 0.006493506493506494,
#  'structur': 0.0016233766233766235,
#  'student': 0.008116883116883116,
#  'studi': 0.0016233766233766235,
#  'stuff': 0.0016233766233766235,
#  'subject': 0.0016233766233766235,
#  'success': 0.0016233766233766235,
#  'such': 0.0016233766233766235,
#  'suffer': 0.0016233766233766235,
#  'sure': 0.0016233766233766235,
#  'system': 0.0016233766233766235,
#  'take': 0.008116883116883116,
#  'talk': 0.003246753246753247,
#  'teach': 0.0016233766233766235,
#  'term': 0.0016233766233766235,
#  'test': 0.003246753246753247,
#  'textbook': 0.0016233766233766235,
#  'than': 0.0016233766233766235,
#  'that': 0.012987012987012988,
#  'the': 0.030844155844155844,
#  'their': 0.006493506493506494,
#  'them': 0.006493506493506494,
#  'then': 0.0016233766233766235,
#  'there': 0.00487012987012987,
#  'these': 0.0016233766233766235,
#  'they': 0.01948051948051948,
#  'thing': 0.0016233766233766235,
#  'think': 0.012987012987012988,
#  'this': 0.00974025974025974,
#  'thousand': 0.0016233766233766235,
#  'time': 0.008116883116883116,
#  'to': 0.016233766233766232,
#  'togeth': 0.0016233766233766235,
#  'too': 0.003246753246753247,
#  'took': 0.0016233766233766235,
#  'topic': 0.00487012987012987,
#  'total_words': 1.0,
#  'translat': 0.0016233766233766235,
#  'tri': 0.00487012987012987,
#  'type': 0.0016233766233766235,
#  'udi': 0.0016233766233766235,
#  'upper': 0.0016233766233766235,
#  'varieti': 0.0016233766233766235,
#  'want': 0.0016233766233766235,
#  'was': 0.0016233766233766235,
#  'way': 0.0016233766233766235,
#  'week': 0.0016233766233766235,
#  'well': 0.003246753246753247,
#  'wellesley': 0.0016233766233766235,
#  'what': 0.00487012987012987,
#  'where': 0.0016233766233766235,
#  'who': 0.0016233766233766235,
#  'with': 0.003246753246753247,
#  'work': 0.00974025974025974,
#  'world': 0.0016233766233766235,
#  'would': 0.0016233766233766235,
#  'write': 0.00487012987012987}

# %%
def distance_between(resp, ruhl):
    nresp = normalize(resp)
    nruhl = normalize(ruhl)
